# %%
import os
import glob
import pandas as pd

# %%
import pydicom
in_dir = "/slurm_storage/mbopf/projects/mwb/imaging_utils/"
#in_dir = "/slurm_storage/mbopf/data/PedTB/renamed/"
glob_str = "*.dcm"

for file in glob.glob(in_dir + glob_str):
    ds = pydicom.read_file(file)
    basename = os.path.basename(file)
    print('\n\n#######################')
    print(basename)
    print('#######################')
    print(ds)
# Out:
# #######################
# 0221428AP.dcm
# #######################
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 200
# (0002, 0001) File Meta Information Version       OB: b'\x01\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Computed Radiography Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.392.200036.9125.9.0.319805827.3819678904.1114623080
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.5.3
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_353'
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 594
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'POST_PROCESSED', '', '', '', '', '', '100000']
# (0008, 0016) SOP Class UID                       UI: Computed Radiography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.392.200036.9125.9.0.319805827.3819678904.1114623080
# (0008, 0020) Study Date                          DA: '20140819'
# (0008, 0021) Series Date                         DA: '20140819'
# (0008, 0022) Acquisition Date                    DA: '20140819'
# (0008, 0023) Content Date                        DA: '20140819'
# (0008, 0030) Study Time                          TM: '114428.000'
# (0008, 0031) Series Time                         TM: '114436.000'
# (0008, 0032) Acquisition Time                    TM: '114436.484'
# (0008, 0033) Content Time                        TM: '114444.093'
# (0008, 0050) Accession Number                    SH: '0221428'
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0070) Manufacturer                        LO: 'FUJIFILM Corporation'
# (0008, 0080) Institution Name                    LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'ru_2'
# (0008, 1030) Study Description                   LO: ''
# (0008, 1070) Operators' Name                     PN: 'XRAY'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 0000) Group Length                        UL: 96
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 2.16.840.114151.155332456281129474497729845970939946362
#    ---------
# (0008, 2111) Derivation Description              ST: 'G1.3O#1.60-0.35,MBY0.3AH0.1,C*1.0*1.0'
# (0009, 0000) Private Creator                     UL: 220
# (0009, 0010) Private tag data                    LO: 'FDMS 1.0'
# (0009, 1004) [Image Control Unit]                SH: ''
# (0009, 1005) [Image UID]                         OW: b'\x13\x0f\xd9\x83\xe3\xab\xac\xb8Bo\xcch'
# (0009, 1006) [Route Image UID]                   OW: b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# (0009, 1008) [Image Display Information Version  UL: 0
# (0009, 1009) [Patient Information Version No.]   UL: 0
# (0009, 100c) [Film UID]                          OW: b'\x13\x0f\xd9\x83\xe3\xab\xac\xb8Bo\xcch'
# (0009, 1010) [Exposure Unit Type Code]           CS: 'E9'
# (0009, 1080) [Kanji Hospital Name]               LO: ''
# (0009, 1090) [Distribution Code]                 ST: '12345678'
# (0009, 1092) [Kanji Department Name]             SH: ''
# (0009, 10f0) [Blackening Process Flag]           CS: '01'
# (0009, 10f1) [Processing Information Flag]       ST: '1000'
# (0010, 0000) Group Length                        UL: 70
# (0010, 0010) Patient's Name                      PN: '0221428'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0030) Patient's Birth Date                DA: '20130925'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '010M'
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 0000) Group Length                        UL: 126
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 1004) Plate ID                            LO: 'a47971264c'
# (0018, 1164) Imager Pixel Spacing                DS: [0.10, 0.10]
# (0018, 1400) Acquisition Device Processing Descr LO: 'CHEST PEDIATRICS'
# (0018, 1401) Acquisition Device Processing Code  LO: '0207'
# (0018, 1508) Positioner Type                     CS: 'NONE'
# (0018, 5101) View Position                       CS: ''
# (0018, 6000) Sensitivity                         DS: '1077.0'
# (0019, 0000) Private Creator                     UL: 134
# (0019, 0010) Private tag data                    LO: 'FDMS 1.0'
# (0019, 1015) [Kanji Body Part for Exposure]      LO: ''
# (0019, 1032) [Kanji Menu Name]                   LO: ''
# (0019, 1040) [Image Processing Type]             CS: 'RT'
# (0019, 1050) [EDR Mode]                          CS: '0'
# (0019, 1060) [Radiographer's Code]               SH: '00'
# (0019, 1080) [Reading Position Specification]    IS: '0'
# (0019, 1081) [Reading Sensitivity Center]        IS: '0'
# (0019, 1090) [Film Annotation Character String 1 SH: ''
# (0019, 1091) [Film Annotation Character String 2 SH: ''
# (0020, 0000) Group Length                        UL: 144
# (0020, 000d) Study Instance UID                  UI: 0221428
# (0020, 000e) Series Instance UID                 UI: 1.2.392.200036.9125.3.18417211166104204.64754682273.7125468
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1001'
# (0020, 0012) Acquisition Number                  IS: '16'
# (0020, 0013) Instance Number                     IS: '1001'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0060) Laterality                          CS: ''
# (0021, 0000) Private Creator                     UL: 92
# (0021, 0010) Private tag data                    LO: 'FDMS 1.0'
# (0021, 1010) [FCR Image ID]                      CS: 'A016'
# (0021, 1030) [Set No.]                           CS: ''
# (0021, 1040) [Image No. in the Set]              IS: '1'
# (0021, 1050) [Pair Processing Information]       CS: '01000000'
# (0021, 1080) [Equipment Type-Specific Informatio OB: None
# (0025, 0000) Private Creator                     UL: 58
# (0025, 0010) Private tag data                    LO: 'FDMS 1.0'
# (0025, 1010) [Relative Light Emission Amount Sk] US: 127
# (0025, 1011) [Term of Correction for Each IP Typ US: 0
# (0025, 1012) [Reading Gain Gp]                   US: 163
# (0028, 0000) Group Length                        UL: 172
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME1'
# (0028, 0010) Rows                                US: 1770
# (0028, 0011) Columns                             US: 2370
# (0028, 0030) Pixel Spacing                       DS: [0.10, 0.10]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 10
# (0028, 0102) High Bit                            US: 9
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: '500.0'
# (0028, 1051) Window Width                        DS: '1000.0'
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0029, 0000) Private Creator                     UL: 88
# (0029, 0010) Private tag data                    LO: 'FDMS 1.0'
# (0029, 1020) [Image Scanning Direction]          CS: '000'
# (0029, 1030) [Extended Reading Size Value]       CS: '1A'
# (0029, 1034) [Mag./Reduc. Ratio]                 US: 100
# (0029, 1044) [Line Density Code]                 CS: 'K2'
# (0029, 1050) [Data Compression Code]             CS: '00'
# (0032, 0000) Group Length                        UL: 44
# (0032, 1032) Requesting Physician                PN: 'LABUSCHAGNE-KRUGER^DENISE^^^'
# (0032, 1033) Requesting Service                  LO: ''
# (0040, 0000) Group Length                        UL: 270
# (0040, 0253) Performed Procedure Step ID         SH: '1'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Chest: Two Views PA + Lateral'
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0040, 0000) Group Length                        UL: 174
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'Chest: Two Views PA + Lateral'
#    (0040, 0008)  Scheduled Protocol Code Sequence  1 item(s) ----
#       (0008, 0000) Group Length                        UL: 68
#       (0008, 0100) Code Value                          SH: '30110-1'
#       (0008, 0102) Coding Scheme Designator            SH: 'RXH00'
#       (0008, 0104) Code Meaning                        LO: 'Chest: Two Views PA + Lateral'
#       ---------
#    (0040, 0009) Scheduled Procedure Step ID         SH: '1'
#    (0040, 1001) Requested Procedure ID              SH: '1'
#    ---------
# (0073, 0010) Private Creator                     LO: 'STENTOR'
# (0073, 1001) [Unknown]                           ST: 'unknown'
# (0073, 1002) [Private Creator]                   ST: '10.191.125.133'
# (0073, 1003) [Stentor Remote AETitle Element]    ST: 'B3_CR2'
# (0073, 1004) [Stentor Local AETitle Element]     ST: 'RXH00'
# (0073, 1006) [Stentor Transfer Syntax Value]     LO: '1.2.840.10008.1.2.1'
# (2010, 0000) Group Length                        UL: 74
# (2010, 0010) Image Display Format                ST: 'STANDARD\\1,1'
# (2010, 0030) Annotation Display Format ID        CS: 'CR00'
# (2010, 0040) Film Orientation                    CS: 'LANDSCAPE'
# (2010, 0100) Border Density                      CS: 'BLACK'
# (2010, 0140) Trim                                CS: 'NO'
# (50f1, 0000) Private Creator                     UL: 44
# (50f1, 0010) Private tag data                    LO: 'FDMS 1.0'
# (50f1, 1010) [Film Output Format]                CS: '10'
# (50f1, 1020) [Image Processing Modification Flag CS: '00'
# (7fe0, 0000) Group Length                        UL: 8389812
# (7fe0, 0010) Pixel Data                          OW: Array of 8389800 elements
#
#
# #######################
# 0311983-PA.dcm
# #######################
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 200
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.528.1.1001.100.4.3941.3341.1608898139.20180329022102031
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.528.1.1001.2.20060808.1
# (0002, 0013) Implementation Version Name         SH: 'GEHC_DCM06_1'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'SINGLE PLANE']
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.528.1.1001.100.4.3941.3341.1608898139.20180329022102031
# (0008, 0020) Study Date                          DA: '20150519'
# (0008, 0021) Series Date                         DA: '20150519'
# (0008, 0030) Study Time                          TM: '102102'
# (0008, 0031) Series Time                         TM: '102102'
# (0008, 0050) Accession Number                    SH: 'ME150519M1216'
# (0008, 0060) Modality                            CS: 'SC'
# (0008, 0070) Manufacturer                        LO: 'GE Healthcare IT Radiology'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'REPORT10'
# (0008, 1030) Study Description                   LO: 'null'
# (0008, 103e) Series Description                  LO: 'Secondary Capture'
# (0008, 1090) Manufacturer's Model Name           LO: 'Centricity Radiology RA 600'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: ''
#    (0008, 1155) Referenced SOP Instance UID         UI: ''
#    ---------
# (0008, 2111) Derivation Description              ST: 'Image Export'
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Digital X-Ray Image Storage - For Presentation
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.2.203.4.2147483647.1432022526.79843
#    ---------
# (0010, 0010) Patient's Name                      PN: '0311983'
# (0010, 0020) Patient ID                          LO: '0311983'
# (0010, 0030) Patient's Birth Date                DA: '20060511'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1030) Patient's Weight                    DS: None
# (0018, 1000) Device Serial Number                LO: '1608898139'
# (0018, 1020) Software Versions                   LO: '8.0'
# (0020, 000d) Study Instance UID                  UI: 1.2.528.1.1001.100.2.3941.3341.1608898139.20180329022102046
# (0020, 000e) Series Instance UID                 UI: 1.2.528.1.1001.100.3.3941.3341.1608898139.20180329022102015
# (0020, 0010) Study ID                            SH: '1351441'
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0008) Number of Frames                    IS: '1'
# (0028, 0010) Rows                                US: 1731
# (0028, 0011) Columns                             US: 1777
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: '128.0'
# (0028, 1051) Window Width                        DS: '256.0'
# (0028, 1055) Window Center & Width Explanation   LO: '128/256'
# (0032, 000a) Study Status ID                     CS: '<none>'
# (3109, 0010) Private Creator                     LO: 'Applicare/RadWorks/Version 5.0'
# (3109, 0011) Private Creator                     LO: 'Applicare/RadWorks/Version 6.0/Summary'
# (3109, 1002) [NEW/SEEN Status]                   SH: 'SEEN'
# (3109, 1008) [Receive Origin]                    LO: 'PACS01'
# (3109, 100a) [Receive Date]                      DA: '20180329'
# (3109, 100b) [Receive Time]                      TM: '100839'
# (3109, 1112) [Receive Origin Description]        ST: 'AE_GEPACS'
# (7fe0, 0010) Pixel Data                          OB: Array of 9227962 elements
#
#
# #######################
# 0311959-PA.dcm
# #######################
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 208
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113619.2.203.4.2147483647.1423530450.956201
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.840.113619.6.286
# (0002, 0013) Implementation Version Name         SH: 'AW4_6_05_003_SLE'
# (0002, 0016) Source Application Entity Title     AE: 'AE_GEPACS'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: Digital X-Ray Image Storage - For Presentation
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113619.2.203.4.2147483647.1423530450.956201
# (0008, 0020) Study Date                          DA: '20150210'
# (0008, 0021) Series Date                         DA: '20150210'
# (0008, 0022) Acquisition Date                    DA: '20150210'
# (0008, 0023) Content Date                        DA: '20150210'
# (0008, 002a) Acquisition DateTime                DT: '20150210090728.000000'
# (0008, 0030) Study Time                          TM: '090703.000'
# (0008, 0031) Series Time                         TM: '090707.000'
# (0008, 0032) Acquisition Time                    TM: '090728.000'
# (0008, 0033) Content Time                        TM: '090730.000'
# (0008, 0050) Accession Number                    SH: 'ME150210M1027'
# (0008, 0060) Modality                            CS: 'DX'
# (0008, 0068) Presentation Intent Type            CS: 'FOR PRESENTATION'
# (0008, 0070) Manufacturer                        LO: '"GE Healthcare"'
# (0008, 0080) Institution Name                    LO: "CQ Children's Hospital"
# (0008, 0081) Institution Address                 ST: 'Not Initialized\r\nNot Initialized\r\nChongQing\r\nNot Initialized\r\nNot Initialized'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: '082407220044'
# (0008, 1030) Study Description                   LO: 'null'
# (0008, 103e) Series Description                  LO: 'Chest'
# (0008, 1040) Institutional Department Name       LO: 'Not Initialized'
# (0008, 1050) Performing Physician's Name         PN: 'ma jun ya'
# (0008, 1090) Manufacturer's Model Name           LO: '"Global 1 Platform"'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: ''
#    (0008, 1155) Referenced SOP Instance UID         UI: ''
#    ---------
# (0008, 1120)  Referenced Patient Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: ''
#    (0008, 1155) Referenced SOP Instance UID         UI: ''
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Digital X-Ray Image Storage - For Processing
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.2.203.4.2147483647.1423530448.667922
#    ---------
# (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'T-D3000'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'Chest'
#    ---------
# (0010, 0010) Patient's Name                      PN: '0311959'
# (0010, 0020) Patient ID                          LO: '0311959'
# (0010, 0030) Patient's Birth Date                DA: '20130827'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1030) Patient's Weight                    DS: None
# (0011, 0010) Private Creator                     LO: 'GEMS_GDXE_FALCON_04'
# (0011, 1003) [Processed Series UID]              UI: 1.2.840.113619.2.203.4.2147483647.1423530427.696210
# (0011, 1004) [Acquisition Type]                  CS: 'SE'
# (0011, 1005) [Acquisition UID]                   UI: 1.2.840.113619.2.203.4.2147483647.1423530443.419932
# (0011, 1006) [Image Dose]                        DS: '1.954666'
# (0011, 1009) [Non-Digital Exposures]             SL: 0
# (0011, 1010) [Total Exposures]                   SL: 1
# (0011, 1011) [ROI]                               LT: '<roi>\r\n</roi>\r\n'
# (0011, 1012) [Patient Size String]               LT: 'MEDIUM_ADULT'
# (0011, 1013) [SPS UID]                           UI: 1.2.840.113619.2.203.4.2147483647.1423530125.893586
# (0011, 1015) [Detector ARC Gain]                 DS: '4400.0'
# (0011, 1016) [Processing Debug Info]             LT: Array of 656 elements
# (0011, 1017) [Override mode]                     CS: 'DISABLE'
# (0011, 1019) [Film Speed Selection]              DS: '250.0'
# (0011, 1031) [Detected Field of View]            IS: [1555, 1709, 473, 1709, 473, 312, 1555, 312]
# (0011, 1032) [Adjusted Field of View]            IS: [1555, 1709, 473, 1709, 473, 312, 1555, 312]
# (0011, 1033) [Detected Exposure Index]           DS: '1.6477059070558877'
# (0011, 1034) [Compensated Detector Exposure]     DS: '7.032807376447874'
# (0011, 1035) [Uncompensated Detector Exposure]   DS: '7.525104261684652'
# (0011, 1036) [Median Anatomy Count Value]        DS: '811.0'
# (0011, 1037) [DEI lower and upper limit values]  DS: [0.2, 0.6]
# (0011, 1042) [View IP]                           LO: 'antero-posterior'
# (0011, 1044) [Receptor Type]                     CS: 'TABLE'
# (0011, 1046) [Unknown]                           LO: ['Chest', 'antero-posterior', 'Standard', 'MEDIUM ADULT', 'Factory3']
# (0011, 1047) [Unknown]                           DS: '712.644043'
# (0011, 1059) Private tag data                    CS: 'NORMAL'
# (0011, 1060) Private tag data                    CS: 'VERTICAL'
# (0011, 1064) Private tag data                    CS: 'TRAD_DETECTOR'
# (0011, 1065) Private tag data                    CS: 'GlobalTradTable'
# (0011, 1066) Private tag data                    CS: 'No'
# (0011, 1067) Private tag data                    CS: 'Front'
# (0011, 1068) Private tag data                    CS: '40:f4:a0:0:d7:49'
# (0011, 1069) Private tag data                    CS: '-1.000000'
# (0011, 106b) Private tag data                    US: Array of 16384 elements
# (0011, 106d) Private tag data                    DS: '107.772593'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0060) KVP                                 DS: '60.0'
# (0018, 1020) Software Versions                   LO: 'dm_Platform_release-1.1-16_RainierRefresh'
# (0018, 1030) Protocol Name                       LO: 'CHEST_1_VIEW'
# (0018, 1110) Distance Source to Detector         DS: '1004.0'
# (0018, 1111) Distance Source to Patient          DS: '935.0'
# (0018, 1147) Field of View Shape                 CS: 'RECTANGLE'
# (0018, 1149) Field of View Dimension(s)          IS: [216, 279]
# (0018, 1150) Exposure Time                       IS: '39'
# (0018, 1151) X-Ray Tube Current                  IS: '159'
# (0018, 1152) Exposure                            IS: '6'
# (0018, 1153) Exposure in uAs                     IS: '6170'
# (0018, 115e) Image and Fluoroscopy Area Dose Pro DS: '5.43838'
# (0018, 1160) Filter Type                         SH: 'MULTIPLE'
# (0018, 1164) Imager Pixel Spacing                DS: [0.186255, 0.186255]
# (0018, 1166) Grid                                CS: 'FIXED/FOCUSED'
# (0018, 1190) Focal Spot(s)                       DS: '1.3'
# (0018, 1400) Acquisition Device Processing Descr LO: 'antero-posterior^Factory3'
# (0018, 1405) Relative X-Ray Exposure             IS: '1954'
# (0018, 1508) Positioner Type                     CS: ''
# (0018, 1700) Collimator Shape                    CS: 'POLYGONAL'
# (0018, 1720) Vertices of the Polygonal Collimato IS: [1551, 1706, 471, 1706, 471, 316, 1551, 316]
# (0018, 5101) View Position                       CS: 'AP'
# (0018, 6000) Sensitivity                         DS: '115.31668'
# (0018, 7000) Detector Conditions Nominal Flag    CS: 'YES'
# (0018, 7001) Detector Temperature                DS: '31.683926'
# (0018, 7004) Detector Type                       CS: 'SCINTILLATOR'
# (0018, 7005) Detector Configuration              CS: 'AREA'
# (0018, 700a) Detector ID                         SH: 'PA44579-2'
# (0018, 701a) Detector Binning                    DS: [1, 1]
# (0018, 7020) Detector Element Physical Size      DS: [0.200000, 0.200000]
# (0018, 7022) Detector Element Spacing            DS: [0.200000, 0.200000]
# (0018, 7024) Detector Active Shape               CS: 'RECTANGLE'
# (0018, 7026) Detector Active Dimension(s)        DS: [409.600000, 409.600000]
# (0018, 7030) Field of View Origin                DS: [312, 473]
# (0018, 7032) Field of View Rotation              DS: '0.0'
# (0018, 7034) Field of View Horizontal Flip       CS: 'NO'
# (0018, 704c) Grid Focal Distance                 DS: '1000.0'
# (0018, 7050) Filter Material                     CS: 'COPPER'
# (0018, 7052) Filter Thickness Minimum            DS: '0.0'
# (0018, 7054) Filter Thickness Maximum            DS: '0.0'
# (0018, 7060) Exposure Control Mode               CS: 'AUTOMATIC'
# (0018, 7062) Exposure Control Mode Description   LT: Array of 24 elements
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.186.228179123357108.20150210084052295.405
# (0020, 000e) Series Instance UID                 UI: 1.2.840.113619.2.203.4.2147483647.1423530427.696210
# (0020, 0010) Study ID                            SH: '684501'
# (0020, 0011) Series Number                       IS: '6558'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ['L', 'F']
# (0020, 0062) Image Laterality                    CS: 'U'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1082
# (0028, 0011) Columns                             US: 1397
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 14
# (0028, 0102) High Bit                            US: 13
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0300) Quality Control Image               CS: 'NO'
# (0028, 0301) Burned In Annotation                CS: 'NO'
# (0028, 1040) Pixel Intensity Relationship        CS: 'LOG'
# (0028, 1041) Pixel Intensity Relationship Sign   SS: -1
# (0028, 1050) Window Center                       DS: [8192, 8192, 8192]
# (0028, 1051) Window Width                        DS: [16383, 12288, 24575]
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 1055) Window Center & Width Explanation   LO: ['NORMAL', 'HARDER', 'SOFTER']
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0032, 1060) Requested Procedure Description     LO: 'null'
# (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: ''
#    (0008, 0102) Coding Scheme Designator            SH: ''
#    (0008, 0103) Coding Scheme Version               SH: ''
#    (0008, 0104) Code Meaning                        LO: ''
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20150210'
# (0040, 0245) Performed Procedure Step Start Time TM: '090703.000'
# (0040, 0253) Performed Procedure Step ID         SH: '142353042342702'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Performed Desc'
# (0040, 0260)  Performed Protocol Code Sequence  2 item(s) ----
#    (0008, 0100) Code Value                          SH: 'Default'
#    (0008, 0102) Coding Scheme Designator            SH: '"PRIVATE"'
#    (0008, 0103) Coding Scheme Version               SH: '"0.0"'
#    (0008, 0104) Code Meaning                        LO: 'From Protocol DB'
#    ---------
#    (0008, 0100) Code Value                          SH: 'Default'
#    (0008, 0102) Coding Scheme Designator            SH: '"PRIVATE"'
#    (0008, 0103) Coding Scheme Version               SH: '"0.0"'
#    (0008, 0104) Code Meaning                        LO: 'From Protocol DB'
#    ---------
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'Chest PA/LAT'
#    (0040, 0008)  Scheduled Protocol Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: ''
#       (0008, 0102) Coding Scheme Designator            SH: ''
#       (0008, 0103) Coding Scheme Version               SH: ''
#       (0008, 0104) Code Meaning                        LO: ''
#       ---------
#    (0040, 0009) Scheduled Procedure Step ID         SH: '753031'
#    (0040, 1001) Requested Procedure ID              SH: '684501'
#    ---------
# (0040, 0310) Comments on Radiation Dose          ST: '125%'
# (0040, 0555)  Acquisition Context Sequence  0 item(s) ----
# (0045, 0010) Private Creator                     LO: 'GEMS_FALCON_03'
# (0045, 1055) [A_Coefficients]                    DS: [1.35, 1.15, 1.05, 1.0, 1.0, 0.95, 0.9, 1.0]
# (0045, 1062) [User Window Center]                IS: '4188'
# (0045, 1063) [User Window Width]                 IS: '2605'
# (0045, 1065) [Requested Detector Entrance Dose]  IS: '5000'
# (0045, 1067) [VOI LUT Assymmetry parameter beta] DS: [-0.17, -0.17, -0.17]
# (0045, 1069) [Collimator rotation]               IS: '0'
# (0045, 1072) [Collimator Width]                  IS: '278'
# (0045, 1073) [Collimator Height]                 IS: '215'
# (0054, 0220)  View Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'R-10206'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'antero-posterior'
#    ---------
# (0054, 0410)  Patient Orientation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'F-10450'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'recumbent'
#    ---------
# (0054, 0414)  Patient Gantry Relationship Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'F-10470'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'head-first'
#    ---------
# (0088, 0200)  Icon Image Sequence  1 item(s) ----
#    (0028, 0002) Samples per Pixel                   US: 1
#    (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#    (0028, 0010) Rows                                US: 64
#    (0028, 0011) Columns                             US: 64
#    (0028, 0100) Bits Allocated                      US: 8
#    (0028, 0101) Bits Stored                         US: 8
#    (0028, 0102) High Bit                            US: 7
#    (0028, 0103) Pixel Representation                US: 0
#    (0028, 1040) Pixel Intensity Relationship        CS: 'LOG'
#    (7fe0, 0010) Pixel Data                          OW: Array of 4096 elements
#    ---------
# (2050, 0020) Presentation LUT Shape              CS: 'IDENTITY'
# (7fdf, 0010) Private Creator                     LO: 'GEMS_GDXE_ATHENAV2_INTERNAL_USE'
# (7fdf, 1010) [PPS Stream]                        LT: Array of 76 elements
# (7fdf, 1011) [Pixel Data References (temporary)] LT: Array of 76 elements
# (7fdf, 1020) [Auto Push Tag]                     SS: 1
# (7fdf, 1025) [PPS Status]                        CS: 'COMPLETED'
# (7fe0, 0010) Pixel Data                          OW: Array of 3023108 elements
#
#
# #######################
# rtplan2.dcm
# #######################
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 200
# (0002, 0001) File Meta Information Version       OB: b'\x01\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Computed Radiography Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.392.200036.9125.9.0.319805827.3819678904.1114623080
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.5.3
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_353'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'POST_PROCESSED', '', '', '', '', '', '100000']
# (0008, 0016) SOP Class UID                       UI: Computed Radiography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.392.200036.9125.9.0.319805827.3819678904.1114623080
# (0008, 0020) Study Date                          DA: '20140819'
# (0008, 0021) Series Date                         DA: '20140819'
# (0008, 0022) Acquisition Date                    DA: '20140819'
# (0008, 0023) Content Date                        DA: '20140819'
# (0008, 0030) Study Time                          TM: '114428.000'
# (0008, 0031) Series Time                         TM: '114436.000'
# (0008, 0032) Acquisition Time                    TM: '114436.484'
# (0008, 0033) Content Time                        TM: '114444.093'
# (0008, 0050) Accession Number                    SH: '0221428'
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0070) Manufacturer                        LO: 'FUJIFILM Corporation'
# (0008, 0080) Institution Name                    LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'ru_2'
# (0008, 1030) Study Description                   LO: ''
# (0008, 1070) Operators' Name                     PN: 'XRAY'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 2.16.840.114151.155332456281129474497729845970939946362
#    ---------
# (0008, 2111) Derivation Description              ST: 'G1.3O#1.60-0.35,MBY0.3AH0.1,C*1.0*1.0'
# (0009, 0010) Private Creator                     LO: 'FDMS 1.0'
# (0009, 1004) [Image Control Unit]                SH: ''
# (0009, 1005) [Image UID]                         OW: b'\x13\x0f\xd9\x83\xe3\xab\xac\xb8Bo\xcch'
# (0009, 1006) [Route Image UID]                   OW: b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# (0009, 1008) [Image Display Information Version  UL: 0
# (0009, 1009) [Patient Information Version No.]   UL: 0
# (0009, 100c) [Film UID]                          OW: b'\x13\x0f\xd9\x83\xe3\xab\xac\xb8Bo\xcch'
# (0009, 1010) [Exposure Unit Type Code]           CS: 'E9'
# (0009, 1080) [Kanji Hospital Name]               LO: ''
# (0009, 1090) [Distribution Code]                 ST: '12345678'
# (0009, 1092) [Kanji Department Name]             SH: ''
# (0009, 10f0) [Blackening Process Flag]           CS: '01'
# (0009, 10f1) [Processing Information Flag]       ST: '1000'
# (0010, 0010) Patient's Name                      PN: '0221428'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0030) Patient's Birth Date                DA: '20130925'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '010M'
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 1004) Plate ID                            LO: 'a47971264c'
# (0018, 1164) Imager Pixel Spacing                DS: [0.10, 0.10]
# (0018, 1400) Acquisition Device Processing Descr LO: 'CHEST PEDIATRICS'
# (0018, 1401) Acquisition Device Processing Code  LO: '0207'
# (0018, 1508) Positioner Type                     CS: 'NONE'
# (0018, 5101) View Position                       CS: ''
# (0018, 6000) Sensitivity                         DS: '1077.0'
# (0019, 0010) Private Creator                     LO: 'FDMS 1.0'
# (0019, 1015) [Kanji Body Part for Exposure]      LO: ''
# (0019, 1032) [Kanji Menu Name]                   LO: ''
# (0019, 1040) [Image Processing Type]             CS: 'RT'
# (0019, 1050) [EDR Mode]                          CS: '0'
# (0019, 1060) [Radiographer's Code]               SH: '00'
# (0019, 1080) [Reading Position Specification]    IS: '0'
# (0019, 1081) [Reading Sensitivity Center]        IS: '0'
# (0019, 1090) [Film Annotation Character String 1 SH: ''
# (0019, 1091) [Film Annotation Character String 2 SH: ''
# (0020, 000d) Study Instance UID                  UI: 0221428
# (0020, 000e) Series Instance UID                 UI: 1.2.392.200036.9125.3.18417211166104204.64754682273.7125468
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1001'
# (0020, 0012) Acquisition Number                  IS: '16'
# (0020, 0013) Instance Number                     IS: '1001'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0060) Laterality                          CS: ''
# (0021, 0010) Private Creator                     LO: 'FDMS 1.0'
# (0021, 1010) [FCR Image ID]                      CS: 'A016'
# (0021, 1030) [Set No.]                           CS: ''
# (0021, 1040) [Image No. in the Set]              IS: '1'
# (0021, 1050) [Pair Processing Information]       CS: '01000000'
# (0021, 1080) [Equipment Type-Specific Informatio OB: None
# (0025, 0010) Private Creator                     LO: 'FDMS 1.0'
# (0025, 1010) [Relative Light Emission Amount Sk] US: 127
# (0025, 1011) [Term of Correction for Each IP Typ US: 0
# (0025, 1012) [Reading Gain Gp]                   US: 163
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1770
# (0028, 0011) Columns                             US: 2370
# (0028, 0030) Pixel Spacing                       DS: [0.10, 0.10]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 10
# (0028, 0102) High Bit                            US: 9
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: '500.0'
# (0028, 1051) Window Width                        DS: '1000.0'
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0029, 0010) Private Creator                     LO: 'FDMS 1.0'
# (0029, 1020) [Image Scanning Direction]          CS: '000'
# (0029, 1030) [Extended Reading Size Value]       CS: '1A'
# (0029, 1034) [Mag./Reduc. Ratio]                 US: 100
# (0029, 1044) [Line Density Code]                 CS: 'K2'
# (0029, 1050) [Data Compression Code]             CS: '00'
# (0032, 1032) Requesting Physician                PN: 'LABUSCHAGNE-KRUGER^DENISE^^^'
# (0032, 1033) Requesting Service                  LO: ''
# (0040, 0253) Performed Procedure Step ID         SH: '1'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Chest: Two Views PA + Lateral'
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'Chest: Two Views PA + Lateral'
#    (0040, 0008)  Scheduled Protocol Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '30110-1'
#       (0008, 0102) Coding Scheme Designator            SH: 'RXH00'
#       (0008, 0104) Code Meaning                        LO: 'Chest: Two Views PA + Lateral'
#       ---------
#    (0040, 0009) Scheduled Procedure Step ID         SH: '1'
#    (0040, 1001) Requested Procedure ID              SH: '1'
#    ---------
# (0073, 0010) Private Creator                     LO: 'STENTOR'
# (0073, 1001) [Unknown]                           ST: 'unknown'
# (0073, 1002) [Private Creator]                   ST: '10.191.125.133'
# (0073, 1003) [Stentor Remote AETitle Element]    ST: 'B3_CR2'
# (0073, 1004) [Stentor Local AETitle Element]     ST: 'RXH00'
# (0073, 1006) [Stentor Transfer Syntax Value]     LO: '1.2.840.10008.1.2.1'
# (2010, 0010) Image Display Format                ST: 'STANDARD\\1,1'
# (2010, 0030) Annotation Display Format ID        CS: 'CR00'
# (2010, 0040) Film Orientation                    CS: 'LANDSCAPE'
# (2010, 0100) Border Density                      CS: 'BLACK'
# (2010, 0140) Trim                                CS: 'NO'
# (50f1, 0010) Private Creator                     LO: 'FDMS 1.0'
# (50f1, 1010) [Film Output Format]                CS: '10'
# (50f1, 1020) [Image Processing Modification Flag CS: '00'
# (7fe0, 0010) Pixel Data                          OW: Array of 8389800 elements
#
#
# #######################
# 0522100-AP.dcm
# #######################
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 183
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.25.219181047665313190039273556003903477538
# (0002, 0013) Implementation Version Name         SH: 'MIPAV--NIH'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0008, 0020) Study Date                          DA: '20150515'
# (0008, 0021) Series Date                         DA: '20150515'
# (0008, 0030) Study Time                          TM: ''
# (0008, 0031) Series Time                         TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RG'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: ''
# (0008, 103e) Series Description                  LO: ''
# (0008, 1048) Physician(s) of Record              PN: ''
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0010, 0010) Patient's Name                      PN: 'xxxxxxx'
# (0010, 0020) Patient ID                          LO: '0522100'
# (0010, 0030) Patient's Birth Date                DA: '20141003'
# (0010, 0032) Patient's Birth Time                TM: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 1012) Date of Secondary Capture           DA: '20180130'
# (0018, 1014) Time of Secondary Capture           TM: '113534'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'National Institutes of Health, Center for Information Technology'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'Medical Image Processing, Analysis and Visualization (MIPAV)'
# (0018, 1019) Secondary Capture Device Software V LO: '7.4.0'
# (0018, 1030) Protocol Name                       LO: ''
# (0018, 602c) Physical Delta X                    FD: 100.0
# (0018, 602e) Physical Delta Y                    FD: 100.0
# (0020, 000d) Study Instance UID                  UI: 20150515
# (0020, 000e) Series Instance UID                 UI: 20150515
# (0020, 0010) Study ID                            SH: 'xxxxxx'
# (0020, 0011) Series Number                       IS: None
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 1200
# (0028, 0011) Columns                             US: 1600
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 9110)  Pixel Measures Sequence  1 item(s) ----
#    (0028, 0030) Pixel Spacing                       DS: [1.0, 1.0]
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20150515'
# (0040, 0245) Performed Procedure Step Start Time TM: ''
# (0040, 0253) Performed Procedure Step ID         SH: ''
# (0040, 0254) Performed Procedure Step Descriptio LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 5760000 elements
#
#
# #######################
# 0522100-LAT.dcm
# #######################
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 183
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.25.219181047665313190039273556003903477538
# (0002, 0013) Implementation Version Name         SH: 'MIPAV--NIH'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0008, 0020) Study Date                          DA: '20150515'
# (0008, 0021) Series Date                         DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0031) Series Time                         TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'BI'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: ''
# (0008, 103e) Series Description                  LO: ''
# (0008, 1048) Physician(s) of Record              PN: ''
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0010, 0010) Patient's Name                      PN: 'xxxxx'
# (0010, 0020) Patient ID                          LO: '0522100'
# (0010, 0030) Patient's Birth Date                DA: '20141003'
# (0010, 0032) Patient's Birth Time                TM: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 1012) Date of Secondary Capture           DA: '20180130'
# (0018, 1014) Time of Secondary Capture           TM: '114926'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'National Institutes of Health, Center for Information Technology'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'Medical Image Processing, Analysis and Visualization (MIPAV)'
# (0018, 1019) Secondary Capture Device Software V LO: '7.4.0'
# (0018, 1030) Protocol Name                       LO: ''
# (0018, 602c) Physical Delta X                    FD: 100.0
# (0018, 602e) Physical Delta Y                    FD: 100.0
# (0020, 000d) Study Instance UID                  UI: 20150515
# (0020, 000e) Series Instance UID                 UI: 20150515
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: None
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 1200
# (0028, 0011) Columns                             US: 1600
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 9110)  Pixel Measures Sequence  1 item(s) ----
#    (0028, 0030) Pixel Spacing                       DS: [1.0, 1.0]
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: ''
# (0040, 0245) Performed Procedure Step Start Time TM: ''
# (0040, 0253) Performed Procedure Step ID         SH: ''
# (0040, 0254) Performed Procedure Step Descriptio LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 5760000 elements
#
#
# #######################
# 0522100-AP_mod.dcm
# #######################
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 186
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.25.219181047665313190039273556003903477538
# (0002, 0013) Implementation Version Name         SH: 'MIPAV--NIH'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0008, 0020) Study Date                          DA: '20150515'
# (0008, 0021) Series Date                         DA: '20150515'
# (0008, 0030) Study Time                          TM: ''
# (0008, 0031) Series Time                         TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RG'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: ''
# (0008, 103e) Series Description                  LO: ''
# (0008, 1048) Physician(s) of Record              PN: ''
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0010, 0010) Patient's Name                      PN: 'xxxxxxx'
# (0010, 0020) Patient ID                          LO: '0522100'
# (0010, 0030) Patient's Birth Date                DA: '20141003'
# (0010, 0032) Patient's Birth Time                TM: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 1012) Date of Secondary Capture           DA: '20180130'
# (0018, 1014) Time of Secondary Capture           TM: '113534'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'National Institutes of Health, Center for Information Technology'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'Medical Image Processing, Analysis and Visualization (MIPAV)'
# (0018, 1019) Secondary Capture Device Software V LO: '7.4.0'
# (0018, 1030) Protocol Name                       LO: ''
# (0018, 602c) Physical Delta X                    FD: 100.0
# (0018, 602e) Physical Delta Y                    FD: 100.0
# (0020, 000d) Study Instance UID                  UI: 20150515
# (0020, 000e) Series Instance UID                 UI: 20150515
# (0020, 0010) Study ID                            SH: 'xxxxxx'
# (0020, 0011) Series Number                       IS: None
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 1200
# (0028, 0011) Columns                             US: 1600
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 9110)  Pixel Measures Sequence  1 item(s) ----
#    (0028, 0030) Pixel Spacing                       DS: [1.0, 1.0]
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20150515'
# (0040, 0245) Performed Procedure Step Start Time TM: ''
# (0040, 0253) Performed Procedure Step ID         SH: ''
# (0040, 0254) Performed Procedure Step Descriptio LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 5760000 elements
#
#
# #######################
# 0522100-LAT_mod.dcm
# #######################
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 186
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.25.219181047665313190039273556003903477538
# (0002, 0013) Implementation Version Name         SH: 'MIPAV--NIH'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0008, 0020) Study Date                          DA: '20150515'
# (0008, 0021) Series Date                         DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0031) Series Time                         TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'BI'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: ''
# (0008, 103e) Series Description                  LO: ''
# (0008, 1048) Physician(s) of Record              PN: ''
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0010, 0010) Patient's Name                      PN: 'xxxxx'
# (0010, 0020) Patient ID                          LO: '0522100'
# (0010, 0030) Patient's Birth Date                DA: '20141003'
# (0010, 0032) Patient's Birth Time                TM: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 1012) Date of Secondary Capture           DA: '20180130'
# (0018, 1014) Time of Secondary Capture           TM: '114926'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'National Institutes of Health, Center for Information Technology'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'Medical Image Processing, Analysis and Visualization (MIPAV)'
# (0018, 1019) Secondary Capture Device Software V LO: '7.4.0'
# (0018, 1030) Protocol Name                       LO: ''
# (0018, 602c) Physical Delta X                    FD: 100.0
# (0018, 602e) Physical Delta Y                    FD: 100.0
# (0020, 000d) Study Instance UID                  UI: 20150515
# (0020, 000e) Series Instance UID                 UI: 20150515
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: None
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 1200
# (0028, 0011) Columns                             US: 1600
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 9110)  Pixel Measures Sequence  1 item(s) ----
#    (0028, 0030) Pixel Spacing                       DS: [1.0, 1.0]
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: ''
# (0040, 0245) Performed Procedure Step Start Time TM: ''
# (0040, 0253) Performed Procedure Step ID         SH: ''
# (0040, 0254) Performed Procedure Step Descriptio LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 5760000 elements

# %%
import pydicom
in_dir = "/slurm_storage/mbopf/projects/mwb/imaging_utils/"
#in_dir = "/slurm_storage/mbopf/data/PedTB/renamed/"
glob_str = "*.dcm"

for file in glob.glob(in_dir + glob_str):
    ds = pydicom.read_file(file)
    basename = os.path.basename(file)
    print('-----------------')
    print(basename)
    print('-----------------')
    print(ds)
# Out:
# -----------------
# 0221428AP.dcm
# -----------------
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 200
# (0002, 0001) File Meta Information Version       OB: b'\x01\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Computed Radiography Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.392.200036.9125.9.0.319805827.3819678904.1114623080
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.5.3
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_353'
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 594
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'POST_PROCESSED', '', '', '', '', '', '100000']
# (0008, 0016) SOP Class UID                       UI: Computed Radiography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.392.200036.9125.9.0.319805827.3819678904.1114623080
# (0008, 0020) Study Date                          DA: '20140819'
# (0008, 0021) Series Date                         DA: '20140819'
# (0008, 0022) Acquisition Date                    DA: '20140819'
# (0008, 0023) Content Date                        DA: '20140819'
# (0008, 0030) Study Time                          TM: '114428.000'
# (0008, 0031) Series Time                         TM: '114436.000'
# (0008, 0032) Acquisition Time                    TM: '114436.484'
# (0008, 0033) Content Time                        TM: '114444.093'
# (0008, 0050) Accession Number                    SH: '0221428'
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0070) Manufacturer                        LO: 'FUJIFILM Corporation'
# (0008, 0080) Institution Name                    LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'ru_2'
# (0008, 1030) Study Description                   LO: ''
# (0008, 1070) Operators' Name                     PN: 'XRAY'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 0000) Group Length                        UL: 96
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 2.16.840.114151.155332456281129474497729845970939946362
#    ---------
# (0008, 2111) Derivation Description              ST: 'G1.3O#1.60-0.35,MBY0.3AH0.1,C*1.0*1.0'
# (0009, 0000) Private Creator                     UL: 220
# (0009, 0010) Private tag data                    LO: 'FDMS 1.0'
# (0009, 1004) [Image Control Unit]                SH: ''
# (0009, 1005) [Image UID]                         OW: b'\x13\x0f\xd9\x83\xe3\xab\xac\xb8Bo\xcch'
# (0009, 1006) [Route Image UID]                   OW: b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# (0009, 1008) [Image Display Information Version  UL: 0
# (0009, 1009) [Patient Information Version No.]   UL: 0
# (0009, 100c) [Film UID]                          OW: b'\x13\x0f\xd9\x83\xe3\xab\xac\xb8Bo\xcch'
# (0009, 1010) [Exposure Unit Type Code]           CS: 'E9'
# (0009, 1080) [Kanji Hospital Name]               LO: ''
# (0009, 1090) [Distribution Code]                 ST: '12345678'
# (0009, 1092) [Kanji Department Name]             SH: ''
# (0009, 10f0) [Blackening Process Flag]           CS: '01'
# (0009, 10f1) [Processing Information Flag]       ST: '1000'
# (0010, 0000) Group Length                        UL: 70
# (0010, 0010) Patient's Name                      PN: '0221428'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0030) Patient's Birth Date                DA: '20130925'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '010M'
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 0000) Group Length                        UL: 126
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 1004) Plate ID                            LO: 'a47971264c'
# (0018, 1164) Imager Pixel Spacing                DS: [0.10, 0.10]
# (0018, 1400) Acquisition Device Processing Descr LO: 'CHEST PEDIATRICS'
# (0018, 1401) Acquisition Device Processing Code  LO: '0207'
# (0018, 1508) Positioner Type                     CS: 'NONE'
# (0018, 5101) View Position                       CS: ''
# (0018, 6000) Sensitivity                         DS: '1077.0'
# (0019, 0000) Private Creator                     UL: 134
# (0019, 0010) Private tag data                    LO: 'FDMS 1.0'
# (0019, 1015) [Kanji Body Part for Exposure]      LO: ''
# (0019, 1032) [Kanji Menu Name]                   LO: ''
# (0019, 1040) [Image Processing Type]             CS: 'RT'
# (0019, 1050) [EDR Mode]                          CS: '0'
# (0019, 1060) [Radiographer's Code]               SH: '00'
# (0019, 1080) [Reading Position Specification]    IS: '0'
# (0019, 1081) [Reading Sensitivity Center]        IS: '0'
# (0019, 1090) [Film Annotation Character String 1 SH: ''
# (0019, 1091) [Film Annotation Character String 2 SH: ''
# (0020, 0000) Group Length                        UL: 144
# (0020, 000d) Study Instance UID                  UI: 0221428
# (0020, 000e) Series Instance UID                 UI: 1.2.392.200036.9125.3.18417211166104204.64754682273.7125468
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1001'
# (0020, 0012) Acquisition Number                  IS: '16'
# (0020, 0013) Instance Number                     IS: '1001'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0060) Laterality                          CS: ''
# (0021, 0000) Private Creator                     UL: 92
# (0021, 0010) Private tag data                    LO: 'FDMS 1.0'
# (0021, 1010) [FCR Image ID]                      CS: 'A016'
# (0021, 1030) [Set No.]                           CS: ''
# (0021, 1040) [Image No. in the Set]              IS: '1'
# (0021, 1050) [Pair Processing Information]       CS: '01000000'
# (0021, 1080) [Equipment Type-Specific Informatio OB: None
# (0025, 0000) Private Creator                     UL: 58
# (0025, 0010) Private tag data                    LO: 'FDMS 1.0'
# (0025, 1010) [Relative Light Emission Amount Sk] US: 127
# (0025, 1011) [Term of Correction for Each IP Typ US: 0
# (0025, 1012) [Reading Gain Gp]                   US: 163
# (0028, 0000) Group Length                        UL: 172
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME1'
# (0028, 0010) Rows                                US: 1770
# (0028, 0011) Columns                             US: 2370
# (0028, 0030) Pixel Spacing                       DS: [0.10, 0.10]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 10
# (0028, 0102) High Bit                            US: 9
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: '500.0'
# (0028, 1051) Window Width                        DS: '1000.0'
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0029, 0000) Private Creator                     UL: 88
# (0029, 0010) Private tag data                    LO: 'FDMS 1.0'
# (0029, 1020) [Image Scanning Direction]          CS: '000'
# (0029, 1030) [Extended Reading Size Value]       CS: '1A'
# (0029, 1034) [Mag./Reduc. Ratio]                 US: 100
# (0029, 1044) [Line Density Code]                 CS: 'K2'
# (0029, 1050) [Data Compression Code]             CS: '00'
# (0032, 0000) Group Length                        UL: 44
# (0032, 1032) Requesting Physician                PN: 'LABUSCHAGNE-KRUGER^DENISE^^^'
# (0032, 1033) Requesting Service                  LO: ''
# (0040, 0000) Group Length                        UL: 270
# (0040, 0253) Performed Procedure Step ID         SH: '1'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Chest: Two Views PA + Lateral'
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0040, 0000) Group Length                        UL: 174
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'Chest: Two Views PA + Lateral'
#    (0040, 0008)  Scheduled Protocol Code Sequence  1 item(s) ----
#       (0008, 0000) Group Length                        UL: 68
#       (0008, 0100) Code Value                          SH: '30110-1'
#       (0008, 0102) Coding Scheme Designator            SH: 'RXH00'
#       (0008, 0104) Code Meaning                        LO: 'Chest: Two Views PA + Lateral'
#       ---------
#    (0040, 0009) Scheduled Procedure Step ID         SH: '1'
#    (0040, 1001) Requested Procedure ID              SH: '1'
#    ---------
# (0073, 0010) Private Creator                     LO: 'STENTOR'
# (0073, 1001) [Unknown]                           ST: 'unknown'
# (0073, 1002) [Private Creator]                   ST: '10.191.125.133'
# (0073, 1003) [Stentor Remote AETitle Element]    ST: 'B3_CR2'
# (0073, 1004) [Stentor Local AETitle Element]     ST: 'RXH00'
# (0073, 1006) [Stentor Transfer Syntax Value]     LO: '1.2.840.10008.1.2.1'
# (2010, 0000) Group Length                        UL: 74
# (2010, 0010) Image Display Format                ST: 'STANDARD\\1,1'
# (2010, 0030) Annotation Display Format ID        CS: 'CR00'
# (2010, 0040) Film Orientation                    CS: 'LANDSCAPE'
# (2010, 0100) Border Density                      CS: 'BLACK'
# (2010, 0140) Trim                                CS: 'NO'
# (50f1, 0000) Private Creator                     UL: 44
# (50f1, 0010) Private tag data                    LO: 'FDMS 1.0'
# (50f1, 1010) [Film Output Format]                CS: '10'
# (50f1, 1020) [Image Processing Modification Flag CS: '00'
# (7fe0, 0000) Group Length                        UL: 8389812
# (7fe0, 0010) Pixel Data                          OW: Array of 8389800 elements
# -----------------
# 0311983-PA.dcm
# -----------------
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 200
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.528.1.1001.100.4.3941.3341.1608898139.20180329022102031
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.528.1.1001.2.20060808.1
# (0002, 0013) Implementation Version Name         SH: 'GEHC_DCM06_1'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'SINGLE PLANE']
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.528.1.1001.100.4.3941.3341.1608898139.20180329022102031
# (0008, 0020) Study Date                          DA: '20150519'
# (0008, 0021) Series Date                         DA: '20150519'
# (0008, 0030) Study Time                          TM: '102102'
# (0008, 0031) Series Time                         TM: '102102'
# (0008, 0050) Accession Number                    SH: 'ME150519M1216'
# (0008, 0060) Modality                            CS: 'SC'
# (0008, 0070) Manufacturer                        LO: 'GE Healthcare IT Radiology'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'REPORT10'
# (0008, 1030) Study Description                   LO: 'null'
# (0008, 103e) Series Description                  LO: 'Secondary Capture'
# (0008, 1090) Manufacturer's Model Name           LO: 'Centricity Radiology RA 600'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: ''
#    (0008, 1155) Referenced SOP Instance UID         UI: ''
#    ---------
# (0008, 2111) Derivation Description              ST: 'Image Export'
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Digital X-Ray Image Storage - For Presentation
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.2.203.4.2147483647.1432022526.79843
#    ---------
# (0010, 0010) Patient's Name                      PN: '0311983'
# (0010, 0020) Patient ID                          LO: '0311983'
# (0010, 0030) Patient's Birth Date                DA: '20060511'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1030) Patient's Weight                    DS: None
# (0018, 1000) Device Serial Number                LO: '1608898139'
# (0018, 1020) Software Versions                   LO: '8.0'
# (0020, 000d) Study Instance UID                  UI: 1.2.528.1.1001.100.2.3941.3341.1608898139.20180329022102046
# (0020, 000e) Series Instance UID                 UI: 1.2.528.1.1001.100.3.3941.3341.1608898139.20180329022102015
# (0020, 0010) Study ID                            SH: '1351441'
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0008) Number of Frames                    IS: '1'
# (0028, 0010) Rows                                US: 1731
# (0028, 0011) Columns                             US: 1777
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: '128.0'
# (0028, 1051) Window Width                        DS: '256.0'
# (0028, 1055) Window Center & Width Explanation   LO: '128/256'
# (0032, 000a) Study Status ID                     CS: '<none>'
# (3109, 0010) Private Creator                     LO: 'Applicare/RadWorks/Version 5.0'
# (3109, 0011) Private Creator                     LO: 'Applicare/RadWorks/Version 6.0/Summary'
# (3109, 1002) [NEW/SEEN Status]                   SH: 'SEEN'
# (3109, 1008) [Receive Origin]                    LO: 'PACS01'
# (3109, 100a) [Receive Date]                      DA: '20180329'
# (3109, 100b) [Receive Time]                      TM: '100839'
# (3109, 1112) [Receive Origin Description]        ST: 'AE_GEPACS'
# (7fe0, 0010) Pixel Data                          OB: Array of 9227962 elements
# -----------------
# 0311959-PA.dcm
# -----------------
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 208
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113619.2.203.4.2147483647.1423530450.956201
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.840.113619.6.286
# (0002, 0013) Implementation Version Name         SH: 'AW4_6_05_003_SLE'
# (0002, 0016) Source Application Entity Title     AE: 'AE_GEPACS'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: Digital X-Ray Image Storage - For Presentation
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113619.2.203.4.2147483647.1423530450.956201
# (0008, 0020) Study Date                          DA: '20150210'
# (0008, 0021) Series Date                         DA: '20150210'
# (0008, 0022) Acquisition Date                    DA: '20150210'
# (0008, 0023) Content Date                        DA: '20150210'
# (0008, 002a) Acquisition DateTime                DT: '20150210090728.000000'
# (0008, 0030) Study Time                          TM: '090703.000'
# (0008, 0031) Series Time                         TM: '090707.000'
# (0008, 0032) Acquisition Time                    TM: '090728.000'
# (0008, 0033) Content Time                        TM: '090730.000'
# (0008, 0050) Accession Number                    SH: 'ME150210M1027'
# (0008, 0060) Modality                            CS: 'DX'
# (0008, 0068) Presentation Intent Type            CS: 'FOR PRESENTATION'
# (0008, 0070) Manufacturer                        LO: '"GE Healthcare"'
# (0008, 0080) Institution Name                    LO: "CQ Children's Hospital"
# (0008, 0081) Institution Address                 ST: 'Not Initialized\r\nNot Initialized\r\nChongQing\r\nNot Initialized\r\nNot Initialized'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: '082407220044'
# (0008, 1030) Study Description                   LO: 'null'
# (0008, 103e) Series Description                  LO: 'Chest'
# (0008, 1040) Institutional Department Name       LO: 'Not Initialized'
# (0008, 1050) Performing Physician's Name         PN: 'ma jun ya'
# (0008, 1090) Manufacturer's Model Name           LO: '"Global 1 Platform"'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: ''
#    (0008, 1155) Referenced SOP Instance UID         UI: ''
#    ---------
# (0008, 1120)  Referenced Patient Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: ''
#    (0008, 1155) Referenced SOP Instance UID         UI: ''
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Digital X-Ray Image Storage - For Processing
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.2.203.4.2147483647.1423530448.667922
#    ---------
# (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'T-D3000'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'Chest'
#    ---------
# (0010, 0010) Patient's Name                      PN: '0311959'
# (0010, 0020) Patient ID                          LO: '0311959'
# (0010, 0030) Patient's Birth Date                DA: '20130827'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1030) Patient's Weight                    DS: None
# (0011, 0010) Private Creator                     LO: 'GEMS_GDXE_FALCON_04'
# (0011, 1003) [Processed Series UID]              UI: 1.2.840.113619.2.203.4.2147483647.1423530427.696210
# (0011, 1004) [Acquisition Type]                  CS: 'SE'
# (0011, 1005) [Acquisition UID]                   UI: 1.2.840.113619.2.203.4.2147483647.1423530443.419932
# (0011, 1006) [Image Dose]                        DS: '1.954666'
# (0011, 1009) [Non-Digital Exposures]             SL: 0
# (0011, 1010) [Total Exposures]                   SL: 1
# (0011, 1011) [ROI]                               LT: '<roi>\r\n</roi>\r\n'
# (0011, 1012) [Patient Size String]               LT: 'MEDIUM_ADULT'
# (0011, 1013) [SPS UID]                           UI: 1.2.840.113619.2.203.4.2147483647.1423530125.893586
# (0011, 1015) [Detector ARC Gain]                 DS: '4400.0'
# (0011, 1016) [Processing Debug Info]             LT: Array of 656 elements
# (0011, 1017) [Override mode]                     CS: 'DISABLE'
# (0011, 1019) [Film Speed Selection]              DS: '250.0'
# (0011, 1031) [Detected Field of View]            IS: [1555, 1709, 473, 1709, 473, 312, 1555, 312]
# (0011, 1032) [Adjusted Field of View]            IS: [1555, 1709, 473, 1709, 473, 312, 1555, 312]
# (0011, 1033) [Detected Exposure Index]           DS: '1.6477059070558877'
# (0011, 1034) [Compensated Detector Exposure]     DS: '7.032807376447874'
# (0011, 1035) [Uncompensated Detector Exposure]   DS: '7.525104261684652'
# (0011, 1036) [Median Anatomy Count Value]        DS: '811.0'
# (0011, 1037) [DEI lower and upper limit values]  DS: [0.2, 0.6]
# (0011, 1042) [View IP]                           LO: 'antero-posterior'
# (0011, 1044) [Receptor Type]                     CS: 'TABLE'
# (0011, 1046) [Unknown]                           LO: ['Chest', 'antero-posterior', 'Standard', 'MEDIUM ADULT', 'Factory3']
# (0011, 1047) [Unknown]                           DS: '712.644043'
# (0011, 1059) Private tag data                    CS: 'NORMAL'
# (0011, 1060) Private tag data                    CS: 'VERTICAL'
# (0011, 1064) Private tag data                    CS: 'TRAD_DETECTOR'
# (0011, 1065) Private tag data                    CS: 'GlobalTradTable'
# (0011, 1066) Private tag data                    CS: 'No'
# (0011, 1067) Private tag data                    CS: 'Front'
# (0011, 1068) Private tag data                    CS: '40:f4:a0:0:d7:49'
# (0011, 1069) Private tag data                    CS: '-1.000000'
# (0011, 106b) Private tag data                    US: Array of 16384 elements
# (0011, 106d) Private tag data                    DS: '107.772593'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0060) KVP                                 DS: '60.0'
# (0018, 1020) Software Versions                   LO: 'dm_Platform_release-1.1-16_RainierRefresh'
# (0018, 1030) Protocol Name                       LO: 'CHEST_1_VIEW'
# (0018, 1110) Distance Source to Detector         DS: '1004.0'
# (0018, 1111) Distance Source to Patient          DS: '935.0'
# (0018, 1147) Field of View Shape                 CS: 'RECTANGLE'
# (0018, 1149) Field of View Dimension(s)          IS: [216, 279]
# (0018, 1150) Exposure Time                       IS: '39'
# (0018, 1151) X-Ray Tube Current                  IS: '159'
# (0018, 1152) Exposure                            IS: '6'
# (0018, 1153) Exposure in uAs                     IS: '6170'
# (0018, 115e) Image and Fluoroscopy Area Dose Pro DS: '5.43838'
# (0018, 1160) Filter Type                         SH: 'MULTIPLE'
# (0018, 1164) Imager Pixel Spacing                DS: [0.186255, 0.186255]
# (0018, 1166) Grid                                CS: 'FIXED/FOCUSED'
# (0018, 1190) Focal Spot(s)                       DS: '1.3'
# (0018, 1400) Acquisition Device Processing Descr LO: 'antero-posterior^Factory3'
# (0018, 1405) Relative X-Ray Exposure             IS: '1954'
# (0018, 1508) Positioner Type                     CS: ''
# (0018, 1700) Collimator Shape                    CS: 'POLYGONAL'
# (0018, 1720) Vertices of the Polygonal Collimato IS: [1551, 1706, 471, 1706, 471, 316, 1551, 316]
# (0018, 5101) View Position                       CS: 'AP'
# (0018, 6000) Sensitivity                         DS: '115.31668'
# (0018, 7000) Detector Conditions Nominal Flag    CS: 'YES'
# (0018, 7001) Detector Temperature                DS: '31.683926'
# (0018, 7004) Detector Type                       CS: 'SCINTILLATOR'
# (0018, 7005) Detector Configuration              CS: 'AREA'
# (0018, 700a) Detector ID                         SH: 'PA44579-2'
# (0018, 701a) Detector Binning                    DS: [1, 1]
# (0018, 7020) Detector Element Physical Size      DS: [0.200000, 0.200000]
# (0018, 7022) Detector Element Spacing            DS: [0.200000, 0.200000]
# (0018, 7024) Detector Active Shape               CS: 'RECTANGLE'
# (0018, 7026) Detector Active Dimension(s)        DS: [409.600000, 409.600000]
# (0018, 7030) Field of View Origin                DS: [312, 473]
# (0018, 7032) Field of View Rotation              DS: '0.0'
# (0018, 7034) Field of View Horizontal Flip       CS: 'NO'
# (0018, 704c) Grid Focal Distance                 DS: '1000.0'
# (0018, 7050) Filter Material                     CS: 'COPPER'
# (0018, 7052) Filter Thickness Minimum            DS: '0.0'
# (0018, 7054) Filter Thickness Maximum            DS: '0.0'
# (0018, 7060) Exposure Control Mode               CS: 'AUTOMATIC'
# (0018, 7062) Exposure Control Mode Description   LT: Array of 24 elements
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.186.228179123357108.20150210084052295.405
# (0020, 000e) Series Instance UID                 UI: 1.2.840.113619.2.203.4.2147483647.1423530427.696210
# (0020, 0010) Study ID                            SH: '684501'
# (0020, 0011) Series Number                       IS: '6558'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ['L', 'F']
# (0020, 0062) Image Laterality                    CS: 'U'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1082
# (0028, 0011) Columns                             US: 1397
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 14
# (0028, 0102) High Bit                            US: 13
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0300) Quality Control Image               CS: 'NO'
# (0028, 0301) Burned In Annotation                CS: 'NO'
# (0028, 1040) Pixel Intensity Relationship        CS: 'LOG'
# (0028, 1041) Pixel Intensity Relationship Sign   SS: -1
# (0028, 1050) Window Center                       DS: [8192, 8192, 8192]
# (0028, 1051) Window Width                        DS: [16383, 12288, 24575]
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 1055) Window Center & Width Explanation   LO: ['NORMAL', 'HARDER', 'SOFTER']
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0032, 1060) Requested Procedure Description     LO: 'null'
# (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: ''
#    (0008, 0102) Coding Scheme Designator            SH: ''
#    (0008, 0103) Coding Scheme Version               SH: ''
#    (0008, 0104) Code Meaning                        LO: ''
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20150210'
# (0040, 0245) Performed Procedure Step Start Time TM: '090703.000'
# (0040, 0253) Performed Procedure Step ID         SH: '142353042342702'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Performed Desc'
# (0040, 0260)  Performed Protocol Code Sequence  2 item(s) ----
#    (0008, 0100) Code Value                          SH: 'Default'
#    (0008, 0102) Coding Scheme Designator            SH: '"PRIVATE"'
#    (0008, 0103) Coding Scheme Version               SH: '"0.0"'
#    (0008, 0104) Code Meaning                        LO: 'From Protocol DB'
#    ---------
#    (0008, 0100) Code Value                          SH: 'Default'
#    (0008, 0102) Coding Scheme Designator            SH: '"PRIVATE"'
#    (0008, 0103) Coding Scheme Version               SH: '"0.0"'
#    (0008, 0104) Code Meaning                        LO: 'From Protocol DB'
#    ---------
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'Chest PA/LAT'
#    (0040, 0008)  Scheduled Protocol Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: ''
#       (0008, 0102) Coding Scheme Designator            SH: ''
#       (0008, 0103) Coding Scheme Version               SH: ''
#       (0008, 0104) Code Meaning                        LO: ''
#       ---------
#    (0040, 0009) Scheduled Procedure Step ID         SH: '753031'
#    (0040, 1001) Requested Procedure ID              SH: '684501'
#    ---------
# (0040, 0310) Comments on Radiation Dose          ST: '125%'
# (0040, 0555)  Acquisition Context Sequence  0 item(s) ----
# (0045, 0010) Private Creator                     LO: 'GEMS_FALCON_03'
# (0045, 1055) [A_Coefficients]                    DS: [1.35, 1.15, 1.05, 1.0, 1.0, 0.95, 0.9, 1.0]
# (0045, 1062) [User Window Center]                IS: '4188'
# (0045, 1063) [User Window Width]                 IS: '2605'
# (0045, 1065) [Requested Detector Entrance Dose]  IS: '5000'
# (0045, 1067) [VOI LUT Assymmetry parameter beta] DS: [-0.17, -0.17, -0.17]
# (0045, 1069) [Collimator rotation]               IS: '0'
# (0045, 1072) [Collimator Width]                  IS: '278'
# (0045, 1073) [Collimator Height]                 IS: '215'
# (0054, 0220)  View Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'R-10206'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'antero-posterior'
#    ---------
# (0054, 0410)  Patient Orientation Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'F-10450'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'recumbent'
#    ---------
# (0054, 0414)  Patient Gantry Relationship Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'F-10470'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'head-first'
#    ---------
# (0088, 0200)  Icon Image Sequence  1 item(s) ----
#    (0028, 0002) Samples per Pixel                   US: 1
#    (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
#    (0028, 0010) Rows                                US: 64
#    (0028, 0011) Columns                             US: 64
#    (0028, 0100) Bits Allocated                      US: 8
#    (0028, 0101) Bits Stored                         US: 8
#    (0028, 0102) High Bit                            US: 7
#    (0028, 0103) Pixel Representation                US: 0
#    (0028, 1040) Pixel Intensity Relationship        CS: 'LOG'
#    (7fe0, 0010) Pixel Data                          OW: Array of 4096 elements
#    ---------
# (2050, 0020) Presentation LUT Shape              CS: 'IDENTITY'
# (7fdf, 0010) Private Creator                     LO: 'GEMS_GDXE_ATHENAV2_INTERNAL_USE'
# (7fdf, 1010) [PPS Stream]                        LT: Array of 76 elements
# (7fdf, 1011) [Pixel Data References (temporary)] LT: Array of 76 elements
# (7fdf, 1020) [Auto Push Tag]                     SS: 1
# (7fdf, 1025) [PPS Status]                        CS: 'COMPLETED'
# (7fe0, 0010) Pixel Data                          OW: Array of 3023108 elements
# -----------------
# rtplan2.dcm
# -----------------
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 200
# (0002, 0001) File Meta Information Version       OB: b'\x01\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Computed Radiography Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.392.200036.9125.9.0.319805827.3819678904.1114623080
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.5.3
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_353'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'POST_PROCESSED', '', '', '', '', '', '100000']
# (0008, 0016) SOP Class UID                       UI: Computed Radiography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.392.200036.9125.9.0.319805827.3819678904.1114623080
# (0008, 0020) Study Date                          DA: '20140819'
# (0008, 0021) Series Date                         DA: '20140819'
# (0008, 0022) Acquisition Date                    DA: '20140819'
# (0008, 0023) Content Date                        DA: '20140819'
# (0008, 0030) Study Time                          TM: '114428.000'
# (0008, 0031) Series Time                         TM: '114436.000'
# (0008, 0032) Acquisition Time                    TM: '114436.484'
# (0008, 0033) Content Time                        TM: '114444.093'
# (0008, 0050) Accession Number                    SH: '0221428'
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0070) Manufacturer                        LO: 'FUJIFILM Corporation'
# (0008, 0080) Institution Name                    LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'ru_2'
# (0008, 1030) Study Description                   LO: ''
# (0008, 1070) Operators' Name                     PN: 'XRAY'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 2.16.840.114151.155332456281129474497729845970939946362
#    ---------
# (0008, 2111) Derivation Description              ST: 'G1.3O#1.60-0.35,MBY0.3AH0.1,C*1.0*1.0'
# (0009, 0010) Private Creator                     LO: 'FDMS 1.0'
# (0009, 1004) [Image Control Unit]                SH: ''
# (0009, 1005) [Image UID]                         OW: b'\x13\x0f\xd9\x83\xe3\xab\xac\xb8Bo\xcch'
# (0009, 1006) [Route Image UID]                   OW: b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# (0009, 1008) [Image Display Information Version  UL: 0
# (0009, 1009) [Patient Information Version No.]   UL: 0
# (0009, 100c) [Film UID]                          OW: b'\x13\x0f\xd9\x83\xe3\xab\xac\xb8Bo\xcch'
# (0009, 1010) [Exposure Unit Type Code]           CS: 'E9'
# (0009, 1080) [Kanji Hospital Name]               LO: ''
# (0009, 1090) [Distribution Code]                 ST: '12345678'
# (0009, 1092) [Kanji Department Name]             SH: ''
# (0009, 10f0) [Blackening Process Flag]           CS: '01'
# (0009, 10f1) [Processing Information Flag]       ST: '1000'
# (0010, 0010) Patient's Name                      PN: '0221428'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0030) Patient's Birth Date                DA: '20130925'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '010M'
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 1004) Plate ID                            LO: 'a47971264c'
# (0018, 1164) Imager Pixel Spacing                DS: [0.10, 0.10]
# (0018, 1400) Acquisition Device Processing Descr LO: 'CHEST PEDIATRICS'
# (0018, 1401) Acquisition Device Processing Code  LO: '0207'
# (0018, 1508) Positioner Type                     CS: 'NONE'
# (0018, 5101) View Position                       CS: ''
# (0018, 6000) Sensitivity                         DS: '1077.0'
# (0019, 0010) Private Creator                     LO: 'FDMS 1.0'
# (0019, 1015) [Kanji Body Part for Exposure]      LO: ''
# (0019, 1032) [Kanji Menu Name]                   LO: ''
# (0019, 1040) [Image Processing Type]             CS: 'RT'
# (0019, 1050) [EDR Mode]                          CS: '0'
# (0019, 1060) [Radiographer's Code]               SH: '00'
# (0019, 1080) [Reading Position Specification]    IS: '0'
# (0019, 1081) [Reading Sensitivity Center]        IS: '0'
# (0019, 1090) [Film Annotation Character String 1 SH: ''
# (0019, 1091) [Film Annotation Character String 2 SH: ''
# (0020, 000d) Study Instance UID                  UI: 0221428
# (0020, 000e) Series Instance UID                 UI: 1.2.392.200036.9125.3.18417211166104204.64754682273.7125468
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1001'
# (0020, 0012) Acquisition Number                  IS: '16'
# (0020, 0013) Instance Number                     IS: '1001'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0060) Laterality                          CS: ''
# (0021, 0010) Private Creator                     LO: 'FDMS 1.0'
# (0021, 1010) [FCR Image ID]                      CS: 'A016'
# (0021, 1030) [Set No.]                           CS: ''
# (0021, 1040) [Image No. in the Set]              IS: '1'
# (0021, 1050) [Pair Processing Information]       CS: '01000000'
# (0021, 1080) [Equipment Type-Specific Informatio OB: None
# (0025, 0010) Private Creator                     LO: 'FDMS 1.0'
# (0025, 1010) [Relative Light Emission Amount Sk] US: 127
# (0025, 1011) [Term of Correction for Each IP Typ US: 0
# (0025, 1012) [Reading Gain Gp]                   US: 163
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1770
# (0028, 0011) Columns                             US: 2370
# (0028, 0030) Pixel Spacing                       DS: [0.10, 0.10]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 10
# (0028, 0102) High Bit                            US: 9
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: '500.0'
# (0028, 1051) Window Width                        DS: '1000.0'
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0029, 0010) Private Creator                     LO: 'FDMS 1.0'
# (0029, 1020) [Image Scanning Direction]          CS: '000'
# (0029, 1030) [Extended Reading Size Value]       CS: '1A'
# (0029, 1034) [Mag./Reduc. Ratio]                 US: 100
# (0029, 1044) [Line Density Code]                 CS: 'K2'
# (0029, 1050) [Data Compression Code]             CS: '00'
# (0032, 1032) Requesting Physician                PN: 'LABUSCHAGNE-KRUGER^DENISE^^^'
# (0032, 1033) Requesting Service                  LO: ''
# (0040, 0253) Performed Procedure Step ID         SH: '1'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Chest: Two Views PA + Lateral'
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'Chest: Two Views PA + Lateral'
#    (0040, 0008)  Scheduled Protocol Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '30110-1'
#       (0008, 0102) Coding Scheme Designator            SH: 'RXH00'
#       (0008, 0104) Code Meaning                        LO: 'Chest: Two Views PA + Lateral'
#       ---------
#    (0040, 0009) Scheduled Procedure Step ID         SH: '1'
#    (0040, 1001) Requested Procedure ID              SH: '1'
#    ---------
# (0073, 0010) Private Creator                     LO: 'STENTOR'
# (0073, 1001) [Unknown]                           ST: 'unknown'
# (0073, 1002) [Private Creator]                   ST: '10.191.125.133'
# (0073, 1003) [Stentor Remote AETitle Element]    ST: 'B3_CR2'
# (0073, 1004) [Stentor Local AETitle Element]     ST: 'RXH00'
# (0073, 1006) [Stentor Transfer Syntax Value]     LO: '1.2.840.10008.1.2.1'
# (2010, 0010) Image Display Format                ST: 'STANDARD\\1,1'
# (2010, 0030) Annotation Display Format ID        CS: 'CR00'
# (2010, 0040) Film Orientation                    CS: 'LANDSCAPE'
# (2010, 0100) Border Density                      CS: 'BLACK'
# (2010, 0140) Trim                                CS: 'NO'
# (50f1, 0010) Private Creator                     LO: 'FDMS 1.0'
# (50f1, 1010) [Film Output Format]                CS: '10'
# (50f1, 1020) [Image Processing Modification Flag CS: '00'
# (7fe0, 0010) Pixel Data                          OW: Array of 8389800 elements
# -----------------
# 0522100-AP.dcm
# -----------------
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 183
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.25.219181047665313190039273556003903477538
# (0002, 0013) Implementation Version Name         SH: 'MIPAV--NIH'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0008, 0020) Study Date                          DA: '20150515'
# (0008, 0021) Series Date                         DA: '20150515'
# (0008, 0030) Study Time                          TM: ''
# (0008, 0031) Series Time                         TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RG'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: ''
# (0008, 103e) Series Description                  LO: ''
# (0008, 1048) Physician(s) of Record              PN: ''
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0010, 0010) Patient's Name                      PN: 'xxxxxxx'
# (0010, 0020) Patient ID                          LO: '0522100'
# (0010, 0030) Patient's Birth Date                DA: '20141003'
# (0010, 0032) Patient's Birth Time                TM: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 1012) Date of Secondary Capture           DA: '20180130'
# (0018, 1014) Time of Secondary Capture           TM: '113534'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'National Institutes of Health, Center for Information Technology'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'Medical Image Processing, Analysis and Visualization (MIPAV)'
# (0018, 1019) Secondary Capture Device Software V LO: '7.4.0'
# (0018, 1030) Protocol Name                       LO: ''
# (0018, 602c) Physical Delta X                    FD: 100.0
# (0018, 602e) Physical Delta Y                    FD: 100.0
# (0020, 000d) Study Instance UID                  UI: 20150515
# (0020, 000e) Series Instance UID                 UI: 20150515
# (0020, 0010) Study ID                            SH: 'xxxxxx'
# (0020, 0011) Series Number                       IS: None
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 1200
# (0028, 0011) Columns                             US: 1600
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 9110)  Pixel Measures Sequence  1 item(s) ----
#    (0028, 0030) Pixel Spacing                       DS: [1.0, 1.0]
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20150515'
# (0040, 0245) Performed Procedure Step Start Time TM: ''
# (0040, 0253) Performed Procedure Step ID         SH: ''
# (0040, 0254) Performed Procedure Step Descriptio LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 5760000 elements
# -----------------
# 0522100-LAT.dcm
# -----------------
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 183
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.25.219181047665313190039273556003903477538
# (0002, 0013) Implementation Version Name         SH: 'MIPAV--NIH'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0008, 0020) Study Date                          DA: '20150515'
# (0008, 0021) Series Date                         DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0031) Series Time                         TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'BI'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: ''
# (0008, 103e) Series Description                  LO: ''
# (0008, 1048) Physician(s) of Record              PN: ''
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0010, 0010) Patient's Name                      PN: 'xxxxx'
# (0010, 0020) Patient ID                          LO: '0522100'
# (0010, 0030) Patient's Birth Date                DA: '20141003'
# (0010, 0032) Patient's Birth Time                TM: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 1012) Date of Secondary Capture           DA: '20180130'
# (0018, 1014) Time of Secondary Capture           TM: '114926'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'National Institutes of Health, Center for Information Technology'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'Medical Image Processing, Analysis and Visualization (MIPAV)'
# (0018, 1019) Secondary Capture Device Software V LO: '7.4.0'
# (0018, 1030) Protocol Name                       LO: ''
# (0018, 602c) Physical Delta X                    FD: 100.0
# (0018, 602e) Physical Delta Y                    FD: 100.0
# (0020, 000d) Study Instance UID                  UI: 20150515
# (0020, 000e) Series Instance UID                 UI: 20150515
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: None
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 1200
# (0028, 0011) Columns                             US: 1600
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 9110)  Pixel Measures Sequence  1 item(s) ----
#    (0028, 0030) Pixel Spacing                       DS: [1.0, 1.0]
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: ''
# (0040, 0245) Performed Procedure Step Start Time TM: ''
# (0040, 0253) Performed Procedure Step ID         SH: ''
# (0040, 0254) Performed Procedure Step Descriptio LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 5760000 elements
# -----------------
# 0522100-AP_mod.dcm
# -----------------
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 186
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.25.219181047665313190039273556003903477538
# (0002, 0013) Implementation Version Name         SH: 'MIPAV--NIH'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0008, 0020) Study Date                          DA: '20150515'
# (0008, 0021) Series Date                         DA: '20150515'
# (0008, 0030) Study Time                          TM: ''
# (0008, 0031) Series Time                         TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RG'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: ''
# (0008, 103e) Series Description                  LO: ''
# (0008, 1048) Physician(s) of Record              PN: ''
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0010, 0010) Patient's Name                      PN: 'xxxxxxx'
# (0010, 0020) Patient ID                          LO: '0522100'
# (0010, 0030) Patient's Birth Date                DA: '20141003'
# (0010, 0032) Patient's Birth Time                TM: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 1012) Date of Secondary Capture           DA: '20180130'
# (0018, 1014) Time of Secondary Capture           TM: '113534'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'National Institutes of Health, Center for Information Technology'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'Medical Image Processing, Analysis and Visualization (MIPAV)'
# (0018, 1019) Secondary Capture Device Software V LO: '7.4.0'
# (0018, 1030) Protocol Name                       LO: ''
# (0018, 602c) Physical Delta X                    FD: 100.0
# (0018, 602e) Physical Delta Y                    FD: 100.0
# (0020, 000d) Study Instance UID                  UI: 20150515
# (0020, 000e) Series Instance UID                 UI: 20150515
# (0020, 0010) Study ID                            SH: 'xxxxxx'
# (0020, 0011) Series Number                       IS: None
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 1200
# (0028, 0011) Columns                             US: 1600
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 9110)  Pixel Measures Sequence  1 item(s) ----
#    (0028, 0030) Pixel Spacing                       DS: [1.0, 1.0]
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20150515'
# (0040, 0245) Performed Procedure Step Start Time TM: ''
# (0040, 0253) Performed Procedure Step ID         SH: ''
# (0040, 0254) Performed Procedure Step Descriptio LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 5760000 elements
# -----------------
# 0522100-LAT_mod.dcm
# -----------------
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 186
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.25.219181047665313190039273556003903477538
# (0002, 0013) Implementation Version Name         SH: 'MIPAV--NIH'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.10008.5.1.4.1.1.7.0.0.0
# (0008, 0020) Study Date                          DA: '20150515'
# (0008, 0021) Series Date                         DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0031) Series Time                         TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'BI'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: ''
# (0008, 103e) Series Description                  LO: ''
# (0008, 1048) Physician(s) of Record              PN: ''
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0010, 0010) Patient's Name                      PN: 'xxxxx'
# (0010, 0020) Patient ID                          LO: '0522100'
# (0010, 0030) Patient's Birth Date                DA: '20141003'
# (0010, 0032) Patient's Birth Time                TM: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: ''
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 4000) Patient Comments                    LT: ''
# (0018, 1012) Date of Secondary Capture           DA: '20180130'
# (0018, 1014) Time of Secondary Capture           TM: '114926'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'National Institutes of Health, Center for Information Technology'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'Medical Image Processing, Analysis and Visualization (MIPAV)'
# (0018, 1019) Secondary Capture Device Software V LO: '7.4.0'
# (0018, 1030) Protocol Name                       LO: ''
# (0018, 602c) Physical Delta X                    FD: 100.0
# (0018, 602e) Physical Delta Y                    FD: 100.0
# (0020, 000d) Study Instance UID                  UI: 20150515
# (0020, 000e) Series Instance UID                 UI: 20150515
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: None
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 3
# (0028, 0004) Photometric Interpretation          CS: 'RGB'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 1200
# (0028, 0011) Columns                             US: 1600
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 9110)  Pixel Measures Sequence  1 item(s) ----
#    (0028, 0030) Pixel Spacing                       DS: [1.0, 1.0]
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: ''
# (0040, 0245) Performed Procedure Step Start Time TM: ''
# (0040, 0253) Performed Procedure Step ID         SH: ''
# (0040, 0254) Performed Procedure Step Descriptio LO: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 5760000 elements
